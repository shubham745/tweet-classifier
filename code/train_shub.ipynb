# %%
#!/usr/bin/env python3


import sys
import operator
import numpy as np
from sklearn import svm
from past import autotranslate
autotranslate(['litcm'])
from litcm import LIT
import re
from sklearn.ensemble import RandomForestClassifier


lit = LIT(labels=['hin', 'eng'], transliteration=False)
#   Dictionary and associated files
en_dict_flname = "en_only"      # English words only
hi_dict_flname = "hi_only"      # Hindi words only
en_2ch_w_flname = "en_2.uniq"   # Most frequent 2-char seq in EN
en_3ch_w_flname = "en_3.uniq"   # Most frequent 3-char seq in EN
hi_2ch_w_flname = "hi_2.uniq"   # Most frequent 2-char seq in HI-roman
hi_3ch_w_flname = "hi_3.uniq"   # Most frequent 3-char seq in HI-roman
max_len =30

# Initialize dictionaries and lists to empty
en_dict = set ()
hi_dict = set ()
en_2ch_w_dict = {}
en_2ch_lst = []
en_3ch_w_dict = {}
en_3ch_lst = []
hi_2ch_w_dict = {}
hi_2ch_lst = []
hi_3ch_w_dict = {}
hi_3ch_lst = []
def load_dict ():
    with open (en_dict_flname) as fl:
        for l in fl:
            en_dict.add (l.strip ())
    
    with open (hi_dict_flname) as fl:
        for l in fl:
            hi_dict.add (l.strip ())

    with open (en_2ch_w_flname) as fl:
        for l in fl:
            arr = [ w for w in l.strip ().split (' ') ]
            en_2ch_w_dict[arr[0]] = float (arr[1])
            en_2ch_lst.append (arr[0])
    
    with open (en_3ch_w_flname) as fl:
        for l in fl:
            arr = [ w for w in l.strip ().split (' ') ]
            en_3ch_w_dict[arr[0]] = float (arr[1])
            en_3ch_lst.append (arr[0])
    
    with open (hi_2ch_w_flname) as fl:
        for l in fl:
            arr = [ w for w in l.strip ().split (' ') ]
            hi_2ch_w_dict[arr[0]] = float (arr[1])
            hi_2ch_lst.append (arr[0])
    
    with open (hi_3ch_w_flname) as fl:
        for l in fl:
            arr = [ w for w in l.strip ().split (' ') ]
            hi_3ch_w_dict[arr[0]] = float (arr[1])
            hi_3ch_lst.append (arr[0])
# Given a sentence 's' return the corresponding feature vector
def mk_vect (s):
    p = s.split(' ')
    res=[]
    t = max_len-len(p)
    if t < 0 :
        t=0
    s = s.strip ()
    s_tagged = lit.identify (s)
   
    ct_en = len (re.findall ('\\Eng', s_tagged))
    ct_hi = len (re.findall ('\\Hin', s_tagged))
    ct_all = ct_en + ct_hi
    
    if ct_all > 0:
        res = [ ct_en/ct_all, ct_hi/ct_all ]
    else:
        res = [ 0.00, 0.00 ]
    ar1 = re.findall(r'\Hin|\Eng',s_tagged)
    v1_en = [2 if w == "Hin" else -2 for w in ar1 ] + [0 for _ in range(max_len- len(ar1)) ]
    v1_en = v1_en[:max_len]
    
    v_en = [ 2 if w in en_dict else -1 for w in p ] 
    v_hi = [ 2 if w in hi_dict else -1 for w in p ]
    for i in range(len(v_en)):
        if(v_en[i] == v_hi[i]):
            v_en[i] = 1
            v_hi[i] = 1
    v_en = v_en + [0 for _ in range(t) ]
    v_hi = v_hi + [0 for _ in range(t) ]
    v_en = v_en[:max_len]
    v_hi = v_hi[:max_len]
    # print (v_en)
    # print (v_hi)
    res.append (sum (v_en) / len (v_en))
    res.append (sum (v_hi) / len (v_hi))

    for i in range(len(v_en)):
        res.append(v1_en[i])
        res.append(v_en[i])
        res.append(v_hi[i])
#     for i in range(max_len-len(p)):
#         res.append(0)
#         res.append(0)
    arr = [ s[i+0] + s[i+1] for i in range(len(s) - 1) ]
    dct = {}
    ct = 0
    for w in arr:
        if w in dct:
            dct[w] += 1
        else:
            dct[w] = 1
        ct += 1

    for k in en_2ch_lst:
        if k in dct:
            res.append (dct[k] * en_2ch_w_dict[k] / ct)
        else:
            res.append (0.00)
    
    arr = [ s[i+0] + s[i+1] for i in range(len(s) - 1) ]
    dct = {}
    ct = 0
    for w in arr:
        if w in dct:
            dct[w] += 1
        else:
            dct[w] = 1
        ct += 1

    for k in hi_2ch_lst:
        if k in dct:
            res.append (dct[k] * hi_2ch_w_dict[k] / ct)
        else:
            res.append (0.00)
    
    arr = [ s[i+0] + s[i+1] + s[i+2] for i in range(len(s) - 2) ]
    dct = {}
    ct = 0
    for w in arr:
        if w in dct:
            dct[w] += 1
        else:
            dct[w] = 1
        ct += 1

    for k in en_3ch_lst:
        if k in dct:
            res.append (dct[k] * en_3ch_w_dict[k] / ct)
        else:
            res.append (0.00)
    
    arr = [ s[i+0] + s[i+1] + s[i+2] for i in range(len(s) - 2) ]
    dct = {}
    ct = 0
    for w in arr:
        if w in dct:
            dct[w] += 1
        else:
            dct[w] = 1
        ct += 1

    for k in hi_3ch_lst:
        if k in dct:
            res.append (dct[k] * hi_3ch_w_dict[k] / ct)
        else:
            res.append (0.00)
    
    return np.array(res)


# Loads sentences in 'x_flname' and labels in 'y_flname'
# Converts sentences to feature vectors and returns it in X (ndarray)
# Labels are returned in Y (ndarray)
def load_data (x_flname, y_flname):
    x_orig = []
    y_orig = []
    with open (x_flname) as fl:
        for l in fl:
            x_orig.append (l.strip ())

    with open (y_flname) as fl:
        for l in fl:
            y_orig.append (int (l.strip ()))

    X = []
    for x in x_orig:
        X.append (mk_vect (x))

    X  = np.array (X)
    Y  = np.array (y_orig)

    return (X, Y, x_orig)

print ("[ ] Loading dictionaries ...", end="")
load_dict ()
print ("\r%-79s" % "[x] Dictionaries loaded.")
# Out:
# [x] Dictionaries loaded.

# %%
print ("[ ] Loading and converting Training/Testing data ...", end="")
# x_flname1 = "all.x"
# y_flname1= "all.y"
x_flname = "x_f.txt"
y_flname = "y_f.txt"
X_mixed, Y_mixed, X_mixed_orig = load_data ("code_mixed.x", "code_mixed.y")
X, Y, X_orig = load_data (x_flname, y_flname)
# X1,Y1,X_orig1 = load_data(x_flname1,y_flname1)
print ("\r%-79s" % "[x] Data loaded and converted.")
# Out:
# [x] Data loaded and converted.

# %%
x_mix=[]
y_mix=[]
x_eng =[]
y_eng =[]
x_eng_orig =[]
p = len(Y)
arr= []
arr1=[]
for i in range(p):
    if(Y[i] == 2):
        x_mix.append(X[i])
        y_mix.append(2)
        arr.append(i)
    if(Y[i] == 0):
        x_eng.append(X[i])
        y_eng.append(0)
        x_eng_orig.append(X_orig[i])
        arr1.append(i)
        
# X = np.delete(X,arr)
# Y = np.delete(Y,arr)
print(len(x_mix))
for name in [x_mix,y_mix,x_eng,y_eng,x_eng_orig]:
    name =np.array(name)
X= np.delete(X,arr+arr1,0)
Y= np.delete(Y,arr+arr1,0)
# Out:
# 2201

# %%
x_mix = np.array(x_mix)
y_mix = np.array(y_mix)
x_eng = np.array(x_eng)
y_eng = np.array(y_eng)
print(X.shape)
print(y_mix.shape)
print(X_mixed.shape)
X1.shape
print(x_eng.shape)
# print(X_mixed)
# Out:
# (12289, 244)
# (2201,)
# (450, 244)
# (4193, 244)

# %%
# Training (600 samples): Nearly 2/3 English, 1/3 Code-Mixed
X_tr = np.concatenate ((x_eng[:2500],X[:2800],x_mix), axis=0)
Y_tr = np.concatenate ((y_eng[:2500],Y[:2800],y_mix), axis=0)    
# X_tr = X[:14000]
# Y_tr = Y[:14000]
# test_no = 1
# if len (sys.argv) > 1:
#     if sys.argv[1] in ('1', '2', '3'):
#         test_no = int (sys.argv[1])

# if test_no == 1:
    # Nearly 50-50 mix of code-mixed and english (500 samples)
X_te = np.concatenate ((X[5000:5550],x_eng[2500:3100], X_mixed), axis=0)
Y_te = np.concatenate ((Y[5000:5550],y_eng[2500:3100], Y_mixed), axis=0)
# X_te = X[14000:]
# Y_te = Y[14000:]
X_sent = X_orig[5000:5550] + x_eng_orig[2500:3100]+ X_mixed_orig
# elif test_no == 2:
#     # All code-mixed (250 samples)
#     X_te = np.concatenate ((X1[1400:], X_mixed[200:]), axis=0)
#     Y_te = np.concatenate ((Y1[1400:], Y_mixed[200:]), axis=0)
#     X_sent = X_orig1[1400:] + X_mixed_orig[200:]
# elif test_no == 3:
#     # Nearly all english (1000 samples)
#     X_te = np.concatenate ((X1[400:], X_mixed[450:]), axis=0)
#     Y_te = np.concatenate ((Y1[400:], Y_mixed[450:]), axis=0)
#     X_sent = X_orig1[400:] + X_mixed_orig[450:]

def result():
    print ("    For a total of %d tweets in test-set: " % Y_te.shape[0])
    en=0
    en_hi=0
    en_mi = 0
    mi = 0
    mi_en=0
    mi_hi=0
    hi = 0
    hi_en = 0
    hi_mi=0
    for i in range(Y_te.shape[0]):
        a = Y_pr[i]
        b = Y_te[i]

        if(Y_pr[i] == Y_te[i]):
            if(Y_pr[i] == 0):
                en +=1
            elif(Y_pr[i] == 1):
                hi +=1
            elif(Y_pr[i] == 2):
                mi +=1
        else:
            if(a== 1 and b==0):
                en_hi += 1
            elif(a == 2 and b == 0):
                en_mi +=1
            elif(a == 0 and b == 1):
                hi_en +=1
            elif(a==2 and b==1):
                hi_mi +=1
            elif(a == 0 and b == 2):
                mi_en +=1
            elif(a == 1 and b==2):
                mi_hi +=1
    print("eng   hi   mix   True_values")
    print(en,end ="  ")
    print(en_hi, end = "  ")
    print(en_mi,end="     ")
    print((en+en_hi+en_mi))
    print(hi_en,end ="  ")
    print(hi, end= "  ")
    print(hi_mi,end = "     ")
    print(hi_en+hi+hi_mi)
    print(mi_en,end = "  ")
    print(mi_hi,end="  ")
    print(mi,end = "     ") 
    print(mi_en+mi_hi+mi)
    print((en+hi_en+mi_en),end = "  ")
    print((hi+en_hi+mi_hi),end= "  ")
    print((mi+en_mi+hi_mi),end= "    ")
    print(mi+en+hi+en_hi+en_mi+hi_en+hi_mi+mi_en+mi_hi)
    print("accuracy : ",end = "")
    print((en+hi+mi)/(Y_te.shape[0])) 
    print("----stats----")
    print("eng :",(en/(en+en_hi+en_mi)))
    print("hindi :",(hi/(hi_en+hi+hi_mi)))
    print("mixed :",(mi/(mi_en+mi_hi+mi)))
    mix = 0
    hi = 0
    en =0
    for i in range(len(Y_tr)):
        if(Y_tr[i] == 2):
            mix+=1
        elif(Y_tr[i] == 1):
            hi+=1
        elif(Y_tr[i] == 0):
            en+=1

    print("------Training--------")
    print("en:",en)
    print("hi:",hi)
    print("mix:",mix)

# %%
# Train the SVM
print ("[ ] Training SVM ...", end="")
sclf = svm.SVC (kernel = 'rbf')
sclf.fit (X_tr, Y_tr)
print ("\r%-79s" % "[x] Training complete.")
print ("    Trained on %d samples." % X_tr.shape[0])


# Test the learned model
print ("[ ] Testing ...", end="")
Y_pr = sclf.predict (X_te)
print ("\r%-79s" % "[x] Testing complete.")
Y_pr1 = sclf.predict(X_mixed)


# Print accuracy
print ("[ ] Calculating accuracy ...", end="")
acc = sum ((Y_te == Y_pr).astype ('int64'))/Y_te.shape[0]
print ("\r%-79s" % "[x] Accuracy calculated.")
print ("    For a total of %d tweets in test-set: " % Y_te.shape[0], end="")
print ("Accuracy = %.2f %%" % (acc * 100.0))
print ("[ ] Calculating accuracy code mixed...", end="")
acc = sum ((Y_mixed == Y_pr1).astype ('int64'))/Y_mixed.shape[0]
print ("\r%-79s" % "[x] Accuracy calculated code mixed.")
print ("    For a total of %d tweets in test-set: " % Y_mixed.shape[0], end="")
print ("Accuracy = %.2f %%" % (acc * 100.0))
result()
# Out:
# [x] Training complete.
#     Trained on 7501 samples.
# [x] Testing complete.
# [x] Accuracy calculated.
#     For a total of 1600 tweets in test-set: Accuracy = 81.44 %
# [x] Accuracy calculated code mixed.
#     For a total of 450 tweets in test-set: Accuracy = 88.89 %
#     For a total of 1600 tweets in test-set:
# eng   hi   mix   True_values
# 537  44  19     600
# 64  366  116     546
# 24  26  400     450
# 625  436  535    1596
# accuracy : 0.814375
# ----stats----
# eng : 0.895
# hindi : 0.6703296703296703
# mixed : 0.8888888888888888
# ------Training--------
# en: 2500
# hi: 2788
# mix: 2201

# %%
# Train the randomForest
print ("[ ] Training Random ...", end="")
clf = RandomForestClassifier(n_jobs=-1,max_depth = 10,criterion = "gini")
clf.fit (X_tr, Y_tr)
print ("\r%-79s" % "[x] Training complete.")
print ("    Trained on %d samples." % X_tr.shape[0])


# Test the learned model
print ("[ ] Testing ...", end="")
Y_pr = clf.predict (X_te)
Y_pr1 = clf.predict(X_mixed)


# Print accuracy
print ("[ ] Calculating accuracy ...", end="")
acc = sum ((Y_te == Y_pr).astype ('int64'))/Y_te.shape[0]
print ("\r%-79s" % "[x] Accuracy calculated.")
print ("    For a total of %d tweets in test-set: " % Y_te.shape[0], end="")
print ("Accuracy = %.2f %%" % (acc * 100.0))
print ("[ ] Calculating accuracy code mixed...", end="")
acc = sum ((Y_mixed == Y_pr1).astype ('int64'))/Y_mixed.shape[0]
print ("\r%-79s" % "[x] Accuracy calculated code mixed.")
print ("    For a total of %d tweets in test-set: " % Y_mixed.shape[0], end="")
print ("Accuracy = %.2f %%" % (acc * 100.0))
result()
# Out:
# [x] Training complete.
#     Trained on 7501 samples.
# [x] Accuracy calculated.
#     For a total of 1600 tweets in test-set: Accuracy = 78.12 %
# [x] Accuracy calculated code mixed.
#     For a total of 450 tweets in test-set: Accuracy = 84.00 %
#     For a total of 1600 tweets in test-set:
# eng   hi   mix   True_values
# 530  36  34     600
# 64  342  140     546
# 23  49  378     450
# 617  427  552    1596
# accuracy : 0.78125
# ----stats----
# eng : 0.8833333333333333
# hindi : 0.6263736263736264
# mixed : 0.84
# ------Training--------
# en: 2500
# hi: 2788
# mix: 2201

# %%
lbl_map = ["English", "Hindi", "Code-Mixed", "Unknown" ]
ch = input ("Do you want per sample results [y/n]: ")
if ch == 'y':
    for l in zip(X_sent, range(Y_te.shape[0])):
        s = l[0]
        act = Y_te[l[1]]
        pr = Y_pr[l[1]]
        if(act != pr):
            print ("[%3d] %s" % (l[1], s))
            print ("    Predicted: %-12s\t Actual: %-12s" % (lbl_map[pr], lbl_map[act]))
            if input ("") == 'q':
                break
# Out:
# Do you want per sample results [y/n]: y
# [  4] acha
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [  5] jab bf ko pta h n he is still wid u to ab konse future ka darr h tuje
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [  8] erosnowsouth shamitabh releases today really liked the movie gr8 acting and storyline
#     Predicted: English     	 Actual: Hindi
#
# [ 11] Its 4pm sir
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 15] bhaitu kaha hain
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 16] go hug her n say sory  tel her hw much u love her   thats it  go 4 a date wid her
#     Predicted: Hindi       	 Actual: Unknown
#
# [ 21] prestige puncture ho gayi guddu ki
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 23] gurmeetramrahim blockbustermsg same to u papa g nd thanksss for ur such a lovely wiahes happy mahashivratri papa g
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 28] Sick mntlity  anyone dnt hve any rght to laugh upon smeones dressng sense or may it b any othr thng  it totally dpnds upon d individual wht heshe wna to do  in life  wht to wear  thnk  etc  etc   Stp bhvng like idiots pls  n laughng upon someone shws ur mntlity n chrctr nt d prsns upon whom u r cmmntng
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 29] someUSER the mere mention of catholics makes my blood rise  and i was raised catholic   rejected somewhere around 5th grade
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 38] Ohhh thatz bad  God knows where our educatn systm is goin  thisisnotacceptable
#     Predicted: English     	 Actual: Hindi
#
# [ 40] Ami tomar sathe kotha bolte chai Bhaijaan
#     Predicted: English     	 Actual: Hindi
#
# [ 42] Bhai aap kaha hai
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 43] hahaha       yeh wala bahut badhiya hai    mala d p
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 46] Koi nhi chota kar denge
#     Predicted: English     	 Actual: Hindi
#
# [ 47] someUSER nov 25 at the san siro   i pray we wouldve gotten back our rhythm before then or well get embarrased
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 49] I think vai app padhtey hongey plzz mai appse milna chata hu
#     Predicted: English     	 Actual: Hindi
#
# [ 58] new glory gang music janet at the superbowl on soundcloud
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 59] rt i_m_manu indvspak 700 liters free petrol for pakistani players if they lose kejriwal p
#     Predicted: English     	 Actual: Hindi
#
# [ 62] chak do fatte aap waleyo punjab tuhade nal a
#     Predicted: English     	 Actual: Hindi
#
# [ 67] october is like the road to wrestlemania in reality   halloween  royal rumble   thanksgiving  elimination chamber   christmas  wrestlemania
#     Predicted: English     	 Actual: Hindi
#
# [ 71] modi ji aage badho pura desh aapke ssath hai
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 74] Last replyyyyy plzz plzzz plzzzz
#     Predicted: English     	 Actual: Hindi
#
# [ 76] ache se samjha ke chali gyi aur mai so gayi
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 77] someUSER aki ta junior saying he inviting max tomorrow lol to chill in the house
#     Predicted: English     	 Actual: Hindi
#
# [ 78] in a plane on the way to bombay after a few years    im gonna be walking around aimlessly sometime in the next couple of days
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 79] Kaise ho ap
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 84] Sir i love u MAIN aapka bhot bada faan hunsir Aap jo Tshart pehnte ho mujhe dedo Sir Main HARYANA se hun Sir jimy No Sir 9991865726
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 88] Or Kuchni
#     Predicted: English     	 Actual: Hindi
#
# [ 91] bhai mujhe aapki film bajrangi bhaijaan ke gaane bhaut pasand  aye
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [ 98] Han yaar
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [100] amazon has deals on home theater items on during the countdown to black friday
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [105] of course its aston villa   played them off the park on saturday   bring it on
#     Predicted: English     	 Actual: Hindi
#
# [106] dosto yai flim tho fulle hit pef hit hoge
#     Predicted: English     	 Actual: Hindi
#
# [107] Thk h
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [112] 4 mints more
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [113] Bhai firki to nahi le rahe ho 4 baje mat kehna 430 baje please
#     Predicted: English     	 Actual: Hindi
#
# [115] ye fhoole wale desh ki janta   ko fool ban rha h
#     Predicted: Hindi       	 Actual: Unknown
#
# [117] A year ago  Mr Jairam Ramesh     I think toilets are more important than temples   When he made these statements He was attacked by the RSS  VHP and BJP   Yesterday  Mr Narendra Modi   build toilets before you build temples  BJP now  Congratulating Narendra Modi for placing development before religion and   giving more importance to toilets than places of worship       Ho raha Bharat Nirman
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [119] if youre on the isle of man next thurs   ill be talking about safe house and signing books at waterstones from 6  30pm   someUSER
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [120] work harder        oh god    aaah aaahh    harder oh my god      aah p p
#     Predicted: Hindi       	 Actual: Unknown
#
# [122] hamare jhansi  u  p   mai bhi sipri  sadar   shar   nagara   sabhi thana chhitron mai satta jor shor se chal raha hai   police iss or dhyan nhi de rahi hai        aam janta pareshan hai in satoriyo se
#     Predicted: English     	 Actual: Hindi
#
# [123] Teri party tujhe hi mubarak humare liye Allah hi kaafi h
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [126] hi sallu bhai 3
#     Predicted: English     	 Actual: Hindi
#
# [128] yes lv u sallu bhaijaan
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [133] someUSER someUSER someUSER someUSER good news i bought candy today   bringing some on tues   if it lasts
#     Predicted: English     	 Actual: Hindi
#
# [136] bhai apni toh lag gai march closing or india ka match
#     Predicted: English     	 Actual: Hindi
#
# [145] Ha thk kha bt har ladki ek jaise ni hoti i known kuch girl aisi hoti h jo money par depend krti h bt sare ladke bhi loyal ni h 50 ladke ladkiya dhokebaj h
#     Predicted: English     	 Actual: Hindi
#
# [146] Hu00c2PPu0178
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [147] beefban indiasdaughter ban saaaalaaa yeah india hai ya china freedom ki maa beehen kardeee
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [148] kuchh naa aa raha tv pe award function ke alawa        ghanta      new year isse achha to dd2 yaa dd metro tha
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [150] sweater ko kamar pe bandh ke ghumne ka tashan p
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [155] man utd v arsenal on sat sees the best defence afc in the league conceded 0  67 pgame against the best attack utd scored 2  67 pgame
#     Predicted: English     	 Actual: Hindi
#
# [156] My reaction when i got to know that Sonia gandhi is in hospital
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [158] 2 mb me ap sabka kya jayega bt ye 2 mb ka app apko 2 mb se jyada mb or paisa dilayega try kre its really work
#     Predicted: English     	 Actual: Hindi
#
# [160] im ok with tradeoff with good compensation to farmers if our youth gets plenty of job opportunities landacquisitionbill
#     Predicted: English     	 Actual: Hindi
#
# [161] amit ji nahi dikh rahe o
#     Predicted: English     	 Actual: Hindi
#
# [164] KASH HAM MIL PATE
#     Predicted: English     	 Actual: Hindi
#
# [166] Bahan chood teri
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [167] Hehe   Ishwar  jaane
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [169] someUSER bin kejariwalji ke free wifi ka wait kar rahe the kya itne dino se
#     Predicted: Hindi       	 Actual: Unknown
#
# [173] navbharattimes aapstorm asli sacchai ye hai ke ager delhi walo ko free ka khane ki aadat na hoti to aap kabhi nhi jeet pati
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [178] super duper like     salla nostalgia la diye
#     Predicted: English     	 Actual: Hindi
#
# [189] wish fifa would make league results and tables a bit more realistic   man utd in relegation zone after 15 games and aston villa in 2nd
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [191] issi mauke ka hi toh humey intezaar tha maukamauka indvssa
#     Predicted: English     	 Actual: Hindi
#
# [195] fake news he ho ni sakta aisa    itni cell me konsa cell pe call aaya he jsko pata krna hi bhaut musqil ho jata he
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [199] Ha ab dekh le
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [200] Sab ko Jana hai uper ok is liye apna dakho salman nahi aaya ga ok aur vo to dog hai na Muslim hai na Hindu hai na vo insan hai sif dog hai ok bye bye
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [201] mujhe mil gaya haii
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [203] ima order some tickets for the senior bowl in january
#     Predicted: English     	 Actual: Hindi
#
# [207] beefban there should be ban on beef throughout the country
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [212] Salman khan me aapka wait kar rahi hu pliz
#     Predicted: English     	 Actual: Hindi
#
# [218] he he he he        thank god ham ladkiyo ko bahar nahi jana padta hai   d
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [225] bechara guddu jab bhi maze lene hi wala rehta hai kachua sir uski band baja dete hai
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [231] Chal padhle eis dhyan se  Gand phati padi h
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [233] guddu ka haseen sapne d v
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [234] You should have taken a naked or half naked pic of him and share it on his fb wall
#     Predicted: English     	 Actual: Hindi
#
# [235] salman flap ab
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [236] beta hum bhi engineering college mein baith ke yhi soch rahe h p
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [237] jab cold hoga tb pata chalega guddu ko
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [241] Hal
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [246] bht
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [247] david letterman had an interesting show on monday   he is located in new york city   because of the hurricane he
#     Predicted: English     	 Actual: Hindi
#
# [250] someUSER i saw the drummer from frankie and the heartstrings in town on saturday
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [251] pakistan follow on bachane ke liye maidan per uteregi indvspak
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [252] hey nevada tweeps remember tomorrow is the last day for early voting   ready   set amp vote   justdoit
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [253] hahahhah  sahi hai      jab bhi staff room ke samne se gujrte the to samose ki hi khusbu ati thi
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [258] sabhi doston ko ganatantra divas ki shubhkamnayen
#     Predicted: English     	 Actual: Hindi
#
# [262] there were number of jansabha with peoples participation of common people of delhi   but these corrupt paid media just black out all such jansabha   if people of delhi did not realize the motive of corrupt parties and paid media once again they will be fooled by corrupt nexeus
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [276] well ab bjp supporters ko anna bhi nahi bhate    kuchh to sharam karo   this is why i support aap
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [283] Tum jaan bhaijan ho ya gayab
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [287] kaise ho bhaijan eagerly waiting for 17th
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [294] Kal  phr  kitne  baje
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [295] cartoonist ne google se nikala hai prestige ka meaninggoogle prestige meaning and see for yourself
#     Predicted: English     	 Actual: Hindi
#
# [296] anmolsoni994 aresame to you kutte india jeet gayi  wontgiveitback indvssa
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [299] rt nehatalejainsan msgyouthicon is nt d movie to b banned moreover it should b compulsory to b watched
#     Predicted: English     	 Actual: Hindi
#
# [300] when i teach a basketball in my own school   were gonna spend the 1st day watching larry bird videos   amp the rest will take care of itself
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [302] bade aaye the india ke saath match khelne ke liye   le li naa india walo ne pungi bajaa ke   liho liho
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [305] okkk
#     Predicted: English     	 Actual: Hindi
#
# [313] Abe tumara plan kya h
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [314] baahar nikkkal
#     Predicted: English     	 Actual: Hindi
#
# [315] Salman sir aapki movie hit hogi
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [316] nahin bhai aur wahan rakhne se koi faida nahin       hamein hi de do       hum phod denge
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [318] Dnt compromise ur career for ur so called gf  coz agr kal ko tu kuch bna ni na to tujhe puchne wali b ni h wo  so abhi smbhl ja nd stdy pe dhyn lga  gf pe to bd me b dhyn lga skta h  b practicle yr
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [319] someUSER someUSER  chaps    im still working on the pix from saturday v blaydon   should be uploaded later tonight phil
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [321] 45 hoge
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [322] aj apne hum sbko bht hurt kiye salmanapse ye umid nhi thi hum sb ko bt m also luv u salman
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [326] m musalman ladki se shadi krna chata hu mare age 25 hai 9818463635 plz col me shadi pka karuga ok plz col me
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [329] Or AAP vo h jo is bar khane ke liye muh laplapa rhe h
#     Predicted: English     	 Actual: Hindi
#
# [330] aaj sabhi superhits filmdekhane chale bbthiseid superdupar film
#     Predicted: English     	 Actual: Hindi
#
# [333] someUSER mate   how are you lads enjoying andy carroll over there   can we have him back in january   were a bit desperate
#     Predicted: English     	 Actual: Hindi
#
# [334] mere man ki baat      bharat ke achche bhavishya ke liye aap
#     Predicted: English     	 Actual: Hindi
#
# [335] Or class me baitha hunud83dude01ud83dude01
#     Predicted: English     	 Actual: Hindi
#
# [336] Saala admin 1 rs  Bik jata h or hamare cnfsn nhi daalta
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [338] delhidecides  kiran bedi will discuss on floor of the house thekiranbedi le kar le bahas vidhan sabha mein haha ho ho hi hi
#     Predicted: English     	 Actual: Hindi
#
# [340] Bahot ho chuki hain teri dillagi  chale bhi aao abb shyam dhalne lagi
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [341] Maat dekho salman ke bajrange bhai jaan movies 2  Salman khan is not a muslim he is a hindu becous Allah sey SAAB SE BAA GUNAA HAIN SHIRK TO Salman kahn shirk kar raha hain 3 KURAN KA farman haain saab se bara gunaa Shirk hain
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [345] ty for making me a woman someUSER said at constitution hall saturday dont ever ever ever ever let someone make u feel like shit
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [355] someUSER damn i dont wanna get on my computer   tomorrow  my harry feels are out of control and the outtakes video broke me
#     Predicted: English     	 Actual: Hindi
#
# [356] Yo di
#     Predicted: English     	 Actual: Hindi
#
# [359] Haha u00f0u0178u02dcu2039
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [363] love uuuu soooo muchhhhhhhhhhh jannatttttttttt
#     Predicted: English     	 Actual: Hindi
#
# [364] Tu project karle
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [366] Nhi j
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [369] or kitna specch m aam logo ki ullu banao gye
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [371] i just did a shit load of typing   my group better call me queen tomorrow
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [375] salman ne reply kiya kya guys
#     Predicted: English     	 Actual: Hindi
#
# [386] rahul gandhi ko landacquisitionbill ka virodh karne ke samay bhagna narendramodi ko is mudde pe samarthan dena hai  whereisrahul
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [388] Kabhi to indiya me raho modi ji kasmir hamara janam shid adikar he 67 sal kangres ne bevkuf banaya ap ko jitaya he ab visvas mat todana piliz sar jitni bhi galt dhara he kasmir me use hatao baki des to ham yowa chalahi lenge
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [390] chup raho    tu kya vugada cm banayato
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [391] i support maharashtra beefban but we need to ditch meat altogether retweet
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [392] Ho ho
#     Predicted: English     	 Actual: Hindi
#
# [394] Tu kitne creditsg ke liye registerg kar rha h
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [397] i thing i notices aaptards has no logic against landacquisitionbill they just waste time by rhetoric now 4 publicity arvindannaback
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [401] 56 ench ka seena thanda pad daya 67 ench ke seene ke saamne  retweet to banta hai jaavedjaaferi aapsweep
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [411] someUSER a betrayed wife is legally allowed to kill her adulterous husband   but may only do so with her bare hands   hong kong
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [412] kab aarahe ho
#     Predicted: Code-Mixed  	 Actual: Hindi
#
# [413] shadi ki baat pe dil mein laddo footing toh acting kaise kariing
#     Predicted: English     	 Actual: Hindi
#
# [416] Agar main sehmat hun Jo b phle se hai to
#     Predicted: Code-Mixed  	 Actual: Hindi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/antonio/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     713             try:
# --> 714                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     715             except Exception:
#
# /home/antonio/anaconda3/lib/python3.5/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     738         try:
# --> 739             msg_list = socket.recv_multipart(mode, copy=copy)
#     740         except zmq.ZMQError as e:
#
# /home/antonio/anaconda3/lib/python3.5/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     357         """
# --> 358         parts = [self.recv(flags, copy=copy, track=track)]
#     359         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:6971)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:6763)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:1931)()
#
# /home/antonio/anaconda3/lib/python3.5/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:7222)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-487-b50abe8de588> in <module>()
#       9             print ("[%3d] %s" % (l[1], s))
#      10             print ("    Predicted: %-12s\t Actual: %-12s" % (lbl_map[pr], lbl_map[act]))
# ---> 11             if input ("") == 'q':
#      12                 break
#
# /home/antonio/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     687             self._parent_ident,
#     688             self._parent_header,
# --> 689             password=False,
#     690         )
#     691
#
# /home/antonio/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     717             except KeyboardInterrupt:
#     718                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 719                 raise KeyboardInterrupt
#     720             else:
#     721                 break
#
# KeyboardInterrupt:

# %%
# Out:
# [x] Accuracy calculated.
#     For a total of 50 tweets in test-set: Accuracy = 72.00 %

# %%
sent = "things have a way"
print(lbl_map[clf.predict(mk_vect(sent))])
# Out:
# English
# /home/antonio/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /home/antonio/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   from ipykernel import kernelapp as app

# %%
# Out:
# 'marks is all i have'

# %%
s = "gupta is all i have mausam bada"
s_tagged = lit.identify (s.strip())
print(s_tagged)
ar1 = re.findall(r'\Hin|\Eng',s_tagged)
print(ar1)
v1_en = [2 if w == "Hin" else -2 for w in ar1 ]
print(v1_en)
# print(map(lambda x: x.group(),re.finditer("\\Eng",s_tagged)))
# Out:
# gupta\Hin is\Eng all\Eng i\Eng have\Hin mausam\Hin bada\Hin
# ['Hin', 'Eng', 'Eng', 'Eng', 'Hin', 'Hin', 'Hin']
# [2, -2, -2, -2, 2, 2, 2]
